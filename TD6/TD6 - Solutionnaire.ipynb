# %% [markdown]
# # MTH3302 : Méthodes probabilistes et statistiques pour l'I.A.
#
# Jonathan Jalbert<br/>
# Professeur adjoint au Département de mathématiques et de génie industriel<br/>
# Polytechnique Montréal<br/>
#
# Les images proviennent du jeu de données publiques *The Extended Yale Face Database B* disponible sur le site http://vision.ucsd.edu/~iskwak/ExtYaleDatabase/ExtYaleB.html.
#
#
# ## TD6 : Reconnaissance faciale avec l'analyse en composantes principales
#
#
# Nous utiliserons des images récupérées de la base de données publique de Yale$^{(1)}$ que vous pouvez trouver sur Moodle. Nous avons choisi les 2 ensembles de telle sorte que l'ensemble de test contienne à la fois des images déjà vues et d'autres tout-à-fait nouvelles. L'objectif final est de mesurer la performance de notre algorithme en comptant le nombre d'exemples bien classifiés.
#
# Plusieurs librairies que nous n'utilisons pas régulièrement dans le cours sont nécessaire. Exécutez la prochaine cellule de code pour installer ces librairies.

# %%
using Pkg
Pkg.add(["Images","Netpbm","ImageMagick","Colors"])
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#     Fetching: [========================================>]  100.0 %
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`

# %%
# Librairies standards du cours
using Statistics, LinearAlgebra, Gadfly, DataFrames

# Librairie pour le traitement des images
# using Images, Netpbm, ImageMagick, QuartzImageIO, Colors
using Images, Netpbm, ImageMagick, Colors

# %% [markdown]
# # 1. Chargement des images d'entraînement
# ___
#
# Les images d'entraînement sont contenues dans le dossier *Train* du jeu de données que vous pouvez récupérer sur Moodle. L'ensemble d'entraînement est constitué de 784 images provenant de 28 personnes différente, soit de 28 images par personne.
#
# Les images sont des visages déjà correctement alignés, ce qui nous permet de nous concentrer directemement sur la reconnaissance des visages.

# %%
# Récupération de tous les noms de fichiers de l'échantillon d'entraînement
file = readdir("Train")
trainFileName = ["Train/"*file[i] for i=1:length(file)];

# %%
# Affichage des 8 photos de la première personne
load.(trainFileName[1:8])
# Out:
# 8-element Array{Base.ReinterpretArray{Gray{Normed{UInt8,8}},2,UInt8,Array{UInt8,2}},1}:
#  [Gray{N0f8}(0.314) Gray{N0f8}(0.314) … Gray{N0f8}(0.263) Gray{N0f8}(0.278); Gray{N0f8}(0.318) Gray{N0f8}(0.31) … Gray{N0f8}(0.239) Gray{N0f8}(0.251); … ; Gray{N0f8}(0.047) Gray{N0f8}(0.047) … Gray{N0f8}(0.055) Gray{N0f8}(0.055); Gray{N0f8}(0.047) Gray{N0f8}(0.047) … Gray{N0f8}(0.047) Gray{N0f8}(0.043)]
#  [Gray{N0f8}(0.369) Gray{N0f8}(0.369) … Gray{N0f8}(0.298) Gray{N0f8}(0.31); Gray{N0f8}(0.341) Gray{N0f8}(0.341) … Gray{N0f8}(0.282) Gray{N0f8}(0.294); … ; Gray{N0f8}(0.02) Gray{N0f8}(0.027) … Gray{N0f8}(0.031) Gray{N0f8}(0.035); Gray{N0f8}(0.016) Gray{N0f8}(0.027) … Gray{N0f8}(0.027) Gray{N0f8}(0.031)]
#  [Gray{N0f8}(0.231) Gray{N0f8}(0.259) … Gray{N0f8}(0.263) Gray{N0f8}(0.227); Gray{N0f8}(0.263) Gray{N0f8}(0.298) … Gray{N0f8}(0.282) Gray{N0f8}(0.282); … ; Gray{N0f8}(0.016) Gray{N0f8}(0.02) … Gray{N0f8}(0.02) Gray{N0f8}(0.024); Gray{N0f8}(0.012) Gray{N0f8}(0.016) … Gray{N0f8}(0.027) Gray{N0f8}(0.027)]
#  [Gray{N0f8}(0.271) Gray{N0f8}(0.278) … Gray{N0f8}(0.212) Gray{N0f8}(0.216); Gray{N0f8}(0.263) Gray{N0f8}(0.271) … Gray{N0f8}(0.212) Gray{N0f8}(0.22); … ; Gray{N0f8}(0.118) Gray{N0f8}(0.129) … Gray{N0f8}(0.09) Gray{N0f8}(0.098); Gray{N0f8}(0.122) Gray{N0f8}(0.122) … Gray{N0f8}(0.09) Gray{N0f8}(0.102)]
#  [Gray{N0f8}(0.208) Gray{N0f8}(0.204) … Gray{N0f8}(0.157) Gray{N0f8}(0.149); Gray{N0f8}(0.204) Gray{N0f8}(0.2) … Gray{N0f8}(0.18) Gray{N0f8}(0.169); … ; Gray{N0f8}(0.157) Gray{N0f8}(0.161) … Gray{N0f8}(0.082) Gray{N0f8}(0.102); Gray{N0f8}(0.145) Gray{N0f8}(0.161) … Gray{N0f8}(0.098) Gray{N0f8}(0.102)]
#  [Gray{N0f8}(0.416) Gray{N0f8}(0.42) … Gray{N0f8}(0.251) Gray{N0f8}(0.22); Gray{N0f8}(0.4) Gray{N0f8}(0.42) … Gray{N0f8}(0.251) Gray{N0f8}(0.227); … ; Gray{N0f8}(0.043) Gray{N0f8}(0.043) … Gray{N0f8}(0.031) Gray{N0f8}(0.035); Gray{N0f8}(0.031) Gray{N0f8}(0.035) … Gray{N0f8}(0.035) Gray{N0f8}(0.035)]
#  [Gray{N0f8}(0.467) Gray{N0f8}(0.467) … Gray{N0f8}(0.2) Gray{N0f8}(0.165); Gray{N0f8}(0.463) Gray{N0f8}(0.471) … Gray{N0f8}(0.2) Gray{N0f8}(0.184); … ; Gray{N0f8}(0.098) Gray{N0f8}(0.102) … Gray{N0f8}(0.027) Gray{N0f8}(0.031); Gray{N0f8}(0.094) Gray{N0f8}(0.082) … Gray{N0f8}(0.031) Gray{N0f8}(0.031)]
#  [Gray{N0f8}(0.353) Gray{N0f8}(0.353) … Gray{N0f8}(0.133) Gray{N0f8}(0.137); Gray{N0f8}(0.353) Gray{N0f8}(0.353) … Gray{N0f8}(0.118) Gray{N0f8}(0.141); … ; Gray{N0f8}(0.169) Gray{N0f8}(0.145) … Gray{N0f8}(0.051) Gray{N0f8}(0.051); Gray{N0f8}(0.173) Gray{N0f8}(0.161) … Gray{N0f8}(0.055) Gray{N0f8}(0.051)]

# %%
# Affichage des 8 photos de la huitième personne
load.(trainFileName[29:36])
# Out:
# 8-element Array{Base.ReinterpretArray{Gray{Normed{UInt8,8}},2,UInt8,Array{UInt8,2}},1}:
#  [Gray{N0f8}(0.337) Gray{N0f8}(0.333) … Gray{N0f8}(0.388) Gray{N0f8}(0.384); Gray{N0f8}(0.31) Gray{N0f8}(0.314) … Gray{N0f8}(0.38) Gray{N0f8}(0.376); … ; Gray{N0f8}(0.286) Gray{N0f8}(0.306) … Gray{N0f8}(0.337) Gray{N0f8}(0.325); Gray{N0f8}(0.282) Gray{N0f8}(0.298) … Gray{N0f8}(0.333) Gray{N0f8}(0.322)]
#  [Gray{N0f8}(0.376) Gray{N0f8}(0.392) … Gray{N0f8}(0.396) Gray{N0f8}(0.396); Gray{N0f8}(0.376) Gray{N0f8}(0.373) … Gray{N0f8}(0.392) Gray{N0f8}(0.392); … ; Gray{N0f8}(0.204) Gray{N0f8}(0.224) … Gray{N0f8}(0.239) Gray{N0f8}(0.227); Gray{N0f8}(0.2) Gray{N0f8}(0.212) … Gray{N0f8}(0.235) Gray{N0f8}(0.224)]
#  [Gray{N0f8}(0.38) Gray{N0f8}(0.388) … Gray{N0f8}(0.373) Gray{N0f8}(0.373); Gray{N0f8}(0.373) Gray{N0f8}(0.38) … Gray{N0f8}(0.369) Gray{N0f8}(0.365); … ; Gray{N0f8}(0.129) Gray{N0f8}(0.133) … Gray{N0f8}(0.137) Gray{N0f8}(0.133); Gray{N0f8}(0.133) Gray{N0f8}(0.141) … Gray{N0f8}(0.133) Gray{N0f8}(0.141)]
#  [Gray{N0f8}(0.263) Gray{N0f8}(0.271) … Gray{N0f8}(0.329) Gray{N0f8}(0.345); Gray{N0f8}(0.255) Gray{N0f8}(0.247) … Gray{N0f8}(0.322) Gray{N0f8}(0.333); … ; Gray{N0f8}(0.345) Gray{N0f8}(0.357) … Gray{N0f8}(0.431) Gray{N0f8}(0.42); Gray{N0f8}(0.337) Gray{N0f8}(0.345) … Gray{N0f8}(0.431) Gray{N0f8}(0.42)]
#  [Gray{N0f8}(0.165) Gray{N0f8}(0.161) … Gray{N0f8}(0.247) Gray{N0f8}(0.275); Gray{N0f8}(0.157) Gray{N0f8}(0.149) … Gray{N0f8}(0.247) Gray{N0f8}(0.263); … ; Gray{N0f8}(0.349) Gray{N0f8}(0.357) … Gray{N0f8}(0.435) Gray{N0f8}(0.416); Gray{N0f8}(0.341) Gray{N0f8}(0.353) … Gray{N0f8}(0.424) Gray{N0f8}(0.416)]
#  [Gray{N0f8}(0.4) Gray{N0f8}(0.416) … Gray{N0f8}(0.369) Gray{N0f8}(0.388); Gray{N0f8}(0.4) Gray{N0f8}(0.404) … Gray{N0f8}(0.369) Gray{N0f8}(0.376); … ; Gray{N0f8}(0.286) Gray{N0f8}(0.29) … Gray{N0f8}(0.286) Gray{N0f8}(0.271); Gray{N0f8}(0.278) Gray{N0f8}(0.294) … Gray{N0f8}(0.275) Gray{N0f8}(0.267)]
#  [Gray{N0f8}(0.357) Gray{N0f8}(0.369) … Gray{N0f8}(0.325) Gray{N0f8}(0.345); Gray{N0f8}(0.357) Gray{N0f8}(0.357) … Gray{N0f8}(0.325) Gray{N0f8}(0.329); … ; Gray{N0f8}(0.373) Gray{N0f8}(0.392) … Gray{N0f8}(0.376) Gray{N0f8}(0.353); Gray{N0f8}(0.369) Gray{N0f8}(0.384) … Gray{N0f8}(0.369) Gray{N0f8}(0.353)]
#  [Gray{N0f8}(0.431) Gray{N0f8}(0.447) … Gray{N0f8}(0.318) Gray{N0f8}(0.349); Gray{N0f8}(0.431) Gray{N0f8}(0.439) … Gray{N0f8}(0.322) Gray{N0f8}(0.329); … ; Gray{N0f8}(0.404) Gray{N0f8}(0.408) … Gray{N0f8}(0.298) Gray{N0f8}(0.282); Gray{N0f8}(0.392) Gray{N0f8}(0.404) … Gray{N0f8}(0.286) Gray{N0f8}(0.275)]

# %%
"""
    imgrayconvert(imageFileName ; columnStack=true ; T=Int64)

Conversion en intensité de gris de l'image du fichier `imageFileName`.

### Arguments
- `imageFileName::string` : le nom du fichier de l'image
- `columnStack::bool=true` : Si `true`, l'image est renvoyée comme un vecteur colonne (option par défaut) 
                             sinon la fonction renvoie la matrice des niveaux de gris.
- `T::DataType=Int64` : Type des éléments de la matrice (Int64 par défaut).

### Details
 
La fonction retourne la matrice ou le vecteur colonne des niveaux de gris.
 
### Examples

\```
 julia> imgrayconvert(imageFileName)
 julia> imgrayconvert(imageFileName ; columnStack=false)
 julia> imgrayconvert(imageFileName ; T=Float64)
\```

"""
function imgrayconvert(imageFileName::String ; columnStack::Bool=true , T::DataType = Int64 )
    im = load(imageFileName)
    X = convert(Array{T},channelview(im))
    if columnStack
        Y = X[:]
    else
        Y = X
    end
    return Y
end
# Out:
# imgrayconvert

# %%
"""
    imshow(X), imshow(X, im_size)

Affiche une matrice ou un vecteur en une image composée de niveau de gris.

### Arguments
- `X::Array{Real}` : Une matrice ou un vecteur colonne à afficher.
- `im_size::Tuple{Int64,Int64}` : Un tuple de Int64 indicant la taille de l'image. 


### Details

L'argument `im_size` n'est nécessaire que si un vecteur colonne est envoyé comme image.

L'échelle des niveaux de gris est ajustée en fonction des valeurs contenues dans X.
 
### Examples

\```
 julia> imshow(X)
 julia> imshow(X, (m₁, m₂))
\```

"""
function imshow(X::Array{<:Real,1}, im_size::Tuple{Int64,Int64})
    
    # scale the eigenvector for display on grayscale
    m = minimum(X)
    M = maximum(X)
    
    Z = (X .- m) / (M-m)
    
    Z = reshape(Z, im_size)

    Gray.(Z)
    
end

function imshow(X::Array{<:Real,2})
    
    # scale the eigenvector for display on grayscale
    m = minimum(X)
    M = maximum(X)
    
    Z = (X .- m) / (M-m)
    
    Gray.(Z)
    
end
# Out:
# imshow (generic function with 2 methods)

# %%
# Chargement des images de l'ensemble d'entrainement. Chaque image correspond à une ligne de la matrice X, 
# chaque pixel à une colonne.

n = length(trainFileName)

im = imgrayconvert(trainFileName[1],columnStack=false)
m₁, m₂ = size(im)
m = m₁ * m₂

X = Array{Float64,2}(undef,n,m)

for i=1:n
   X[i,:] = imgrayconvert(trainFileName[i], columnStack=true) 
end

# %% [markdown]
# # 2. Analyse en composantes principales
#
# Le but de cette section est de réduire la dimension du jeu de données d'entraînement. Nous ferons donc une décomposition en valeurs singulières de l'ensemble d'entraînement.
#
# Les étapes sont les suivantes :
# 1. Centrer chacune des lignes de la matrice des visages d'entraînement pour obtenir la matrice $Z$.
# 2. Effectuer une décomposition en valeurs singulières de $Z$.
# 3. Choisir le nombre de composantes principales requises $k$.

# %% [markdown]
# ## 2.1 Centrer les images de l'ensemble d'entraînement
#
# ### a) Calculez le visage moyen $\bar{X}$ en faisait une moyenne de tous les visages pour chacun des pixels. Affichez le visage moyen avec la fonction `imshow`.

# %%
X̄ = vec(mean(X,dims=1))

X̄ = Int64.(round.(X̄))

imshow(X̄, (m₁, m₂))
# Out:
# 192×168 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.232394)  …  Gray{Float64}(0.176056)
#  Gray{Float64}(0.239437)     Gray{Float64}(0.176056)
#  Gray{Float64}(0.239437)     Gray{Float64}(0.176056)
#  Gray{Float64}(0.232394)     Gray{Float64}(0.176056)
#  Gray{Float64}(0.232394)     Gray{Float64}(0.176056)
#  Gray{Float64}(0.232394)  …  Gray{Float64}(0.176056)
#  Gray{Float64}(0.232394)     Gray{Float64}(0.176056)
#  Gray{Float64}(0.232394)     Gray{Float64}(0.176056)
#  Gray{Float64}(0.232394)     Gray{Float64}(0.176056)
#  Gray{Float64}(0.232394)     Gray{Float64}(0.169014)
#  Gray{Float64}(0.225352)  …  Gray{Float64}(0.169014)
#  Gray{Float64}(0.225352)     Gray{Float64}(0.169014)
#  Gray{Float64}(0.225352)     Gray{Float64}(0.169014)
#  ⋮                        ⋱
#  Gray{Float64}(0.147887)  …  Gray{Float64}(0.105634)
#  Gray{Float64}(0.147887)     Gray{Float64}(0.0985915)
#  Gray{Float64}(0.140845)     Gray{Float64}(0.0915493)
#  Gray{Float64}(0.140845)     Gray{Float64}(0.084507)
#  Gray{Float64}(0.140845)     Gray{Float64}(0.0774648)
#  Gray{Float64}(0.140845)  …  Gray{Float64}(0.0774648)
#  Gray{Float64}(0.161972)     Gray{Float64}(0.0704225)
#  Gray{Float64}(0.161972)     Gray{Float64}(0.0704225)
#  Gray{Float64}(0.15493)      Gray{Float64}(0.0704225)
#  Gray{Float64}(0.15493)      Gray{Float64}(0.0704225)
#  Gray{Float64}(0.15493)   …  Gray{Float64}(0.0774648)
#  Gray{Float64}(0.15493)      Gray{Float64}(0.084507)

# %% [markdown]
# ### b) Calculer la matrice $Z$ centrée des visages de l'ensemble d'entraînement. Ensuite, afficher la différence entre le premier visage  et le visage moyen avec la fonction `imshow`.

# %%
Z = X .- X̄'

imshow(Z[1,:], (m₁, m₂))
# Out:
# 192×168 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.389344)  Gray{Float64}(0.381148)  …  Gray{Float64}(0.385246)
#  Gray{Float64}(0.389344)  Gray{Float64}(0.377049)     Gray{Float64}(0.356557)
#  Gray{Float64}(0.385246)  Gray{Float64}(0.377049)     Gray{Float64}(0.348361)
#  Gray{Float64}(0.385246)  Gray{Float64}(0.385246)     Gray{Float64}(0.352459)
#  Gray{Float64}(0.389344)  Gray{Float64}(0.393443)     Gray{Float64}(0.352459)
#  Gray{Float64}(0.397541)  Gray{Float64}(0.413934)  …  Gray{Float64}(0.340164)
#  Gray{Float64}(0.385246)  Gray{Float64}(0.401639)     Gray{Float64}(0.331967)
#  Gray{Float64}(0.389344)  Gray{Float64}(0.393443)     Gray{Float64}(0.32377)
#  Gray{Float64}(0.401639)  Gray{Float64}(0.397541)     Gray{Float64}(0.327869)
#  Gray{Float64}(0.397541)  Gray{Float64}(0.393443)     Gray{Float64}(0.336066)
#  Gray{Float64}(0.385246)  Gray{Float64}(0.389344)  …  Gray{Float64}(0.340164)
#  Gray{Float64}(0.397541)  Gray{Float64}(0.397541)     Gray{Float64}(0.340164)
#  Gray{Float64}(0.401639)  Gray{Float64}(0.401639)     Gray{Float64}(0.344262)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.258197)  Gray{Float64}(0.25)      …  Gray{Float64}(0.254098)
#  Gray{Float64}(0.233607)  Gray{Float64}(0.217213)     Gray{Float64}(0.266393)
#  Gray{Float64}(0.22541)   Gray{Float64}(0.20082)      Gray{Float64}(0.258197)
#  Gray{Float64}(0.22541)   Gray{Float64}(0.204918)     Gray{Float64}(0.258197)
#  Gray{Float64}(0.20082)   Gray{Float64}(0.204918)     Gray{Float64}(0.29918)
#  Gray{Float64}(0.20082)   Gray{Float64}(0.20082)   …  Gray{Float64}(0.254098)
#  Gray{Float64}(0.184426)  Gray{Float64}(0.184426)     Gray{Float64}(0.233607)
#  Gray{Float64}(0.184426)  Gray{Float64}(0.180328)     Gray{Float64}(0.22541)
#  Gray{Float64}(0.184426)  Gray{Float64}(0.168033)     Gray{Float64}(0.209016)
#  Gray{Float64}(0.155738)  Gray{Float64}(0.151639)     Gray{Float64}(0.213115)
#  Gray{Float64}(0.155738)  Gray{Float64}(0.151639)  …  Gray{Float64}(0.209016)
#  Gray{Float64}(0.155738)  Gray{Float64}(0.151639)     Gray{Float64}(0.192623)

# %% [markdown]
# ## 2.2 Décomposition en valeurs singulières de $Z$.
#
# ### a) Obtenez les matrices $U$ et $V$ ainsi que les valeurs singulières à l'aide de la fonction `svd` et/ou de la fonction `svdvals`.

# %%
F = svd(Z)
V = F.V
U = F.U
γ = F.S
# Out:
# 784-element Array{Float64,1}:
#  145366.58540410956
#  116283.54578458458
#   71856.10687572739
#   45880.911321752625
#   42723.53388098387
#   37496.371108493004
#   36425.79573529994
#   33042.85561828739
#   28329.06004097606
#   27089.112211551314
#   25048.302663733586
#   24102.555521667688
#   21723.66179180548
#       ⋮
#     275.65960719067385
#     272.12860664253117
#     268.93290273412475
#     266.41655751730315
#     263.6369368788763
#     259.4706335402022
#     255.26112389219455
#     252.22280489890326
#     250.364404830339
#     243.74455054587835
#     243.0588407759992
#     236.01825066089208

# %% [markdown]
# ### b) Affichez les premiers vecteurs singuliers de $V$ avec la fonction `imshow`.
#
# Ces composantes représentent les modes de plus grande variabilité. Dans la reconnaissance faciale, elles sont appelées les *eigenfaces*.

# %%
[imshow(V[:,i], (m₁, m₂)) for i=1:8]
# Out:
# 8-element Array{Array{Gray{Float64},2},1}:
#  [Gray{Float64}(0.9107292251853627) Gray{Float64}(0.9164948945663122) … Gray{Float64}(0.19376750258903497) Gray{Float64}(0.20182310901017925); Gray{Float64}(0.9141777607496574) Gray{Float64}(0.9191718891035743) … Gray{Float64}(0.1963205908626086) Gray{Float64}(0.20336495754094075); … ; Gray{Float64}(0.8865170885627993) Gray{Float64}(0.8966850881961288) … Gray{Float64}(0.31431718482450693) Gray{Float64}(0.31941408391763926); Gray{Float64}(0.887711658699544) Gray{Float64}(0.8970956670777862) … Gray{Float64}(0.3067646619362018) Gray{Float64}(0.31015651114115755)]
#  [Gray{Float64}(0.38662039560733813) Gray{Float64}(0.37922479573815565) … Gray{Float64}(0.79362559497293) Gray{Float64}(0.7894349164888059); Gray{Float64}(0.3870319053820727) Gray{Float64}(0.3759867166561922) … Gray{Float64}(0.807207181062791) Gray{Float64}(0.8031260995217393); … ; Gray{Float64}(0.6158275643824649) Gray{Float64}(0.6031245336595037) … Gray{Float64}(0.9352071842409998) Gray{Float64}(0.9345774955039827); Gray{Float64}(0.6425090807285035) Gray{Float64}(0.633235384621517) … Gray{Float64}(0.9321179624044299) Gray{Float64}(0.9336997050122235)]
#  [Gray{Float64}(0.5185679867111935) Gray{Float64}(0.5291060480605824) … Gray{Float64}(0.5216658249200122) Gray{Float64}(0.5069182371121164); Gray{Float64}(0.5193889407890897) Gray{Float64}(0.5321221127536653) … Gray{Float64}(0.5258759744954465) Gray{Float64}(0.5114952451936144); … ; Gray{Float64}(0.3867410801459795) Gray{Float64}(0.3673899353429718) … Gray{Float64}(0.31552183823374347) Gray{Float64}(0.3192925234137132); Gray{Float64}(0.3980491290019898) Gray{Float64}(0.3783617261318863) … Gray{Float64}(0.3139294877793524) Gray{Float64}(0.31389958413024094)]
#  [Gray{Float64}(0.5330362199678003) Gray{Float64}(0.5285987626624455) … Gray{Float64}(0.5253904392882397) Gray{Float64}(0.5361111388364843); Gray{Float64}(0.531732725746923) Gray{Float64}(0.5196063377910801) … Gray{Float64}(0.5206776147878655) Gray{Float64}(0.529157929834918); … ; Gray{Float64}(0.5250501291841759) Gray{Float64}(0.5279644826279031) … Gray{Float64}(0.724096877598194) Gray{Float64}(0.7165537586723557); Gray{Float64}(0.5227276978311783) Gray{Float64}(0.5260096628232837) … Gray{Float64}(0.748462085139661) Gray{Float64}(0.753725144537315)]
#  [Gray{Float64}(0.7977718670473259) Gray{Float64}(0.799524662681948) … Gray{Float64}(0.7997178695295378) Gray{Float64}(0.8009740492347844); Gray{Float64}(0.7994065240932993) Gray{Float64}(0.8028934823530922) … Gray{Float64}(0.7973084055404723) Gray{Float64}(0.8031515007629441); … ; Gray{Float64}(0.726808747316201) Gray{Float64}(0.7347427650869731) … Gray{Float64}(0.7175271793512357) Gray{Float64}(0.7169716625100652); Gray{Float64}(0.726303796012669) Gray{Float64}(0.7329162519383414) … Gray{Float64}(0.7175822825378728) Gray{Float64}(0.7115741205117893)]
#  [Gray{Float64}(0.143786446494764) Gray{Float64}(0.14530296356579778) … Gray{Float64}(0.09549520717698806) Gray{Float64}(0.08557716933832721); Gray{Float64}(0.14653559383134443) Gray{Float64}(0.1534078377043565) … Gray{Float64}(0.10364303102916118) Gray{Float64}(0.0903622526426447); … ; Gray{Float64}(0.2962332444008958) Gray{Float64}(0.278220825308311) … Gray{Float64}(0.16538020428716965) Gray{Float64}(0.15776440491273586); Gray{Float64}(0.2999339034534166) Gray{Float64}(0.28753269552559185) … Gray{Float64}(0.17563335139132139) Gray{Float64}(0.1668664589078271)]
#  [Gray{Float64}(0.4608937813122732) Gray{Float64}(0.46036439168616755) … Gray{Float64}(0.4490666584207363) Gray{Float64}(0.45970464570462954); Gray{Float64}(0.46654687080012813) Gray{Float64}(0.4642212473203346) … Gray{Float64}(0.45717515258512154) Gray{Float64}(0.4645237194185177); … ; Gray{Float64}(0.5070557605183507) Gray{Float64}(0.5093228425613817) … Gray{Float64}(0.6172934958104118) Gray{Float64}(0.6174561454811438); Gray{Float64}(0.4993986161682424) Gray{Float64}(0.5046054455704023) … Gray{Float64}(0.6493122193252179) Gray{Float64}(0.6649989634587674)]
#  [Gray{Float64}(0.5181390350299679) Gray{Float64}(0.5276940606091695) … Gray{Float64}(0.4464749597272116) Gray{Float64}(0.42511169257801545); Gray{Float64}(0.525828293625462) Gray{Float64}(0.5332987455901085) … Gray{Float64}(0.45927372964722635) Gray{Float64}(0.4354418494134965); … ; Gray{Float64}(0.562726310073759) Gray{Float64}(0.5630291417699271) … Gray{Float64}(0.3760551702470493) Gray{Float64}(0.3775462023762323); Gray{Float64}(0.5582660740914195) Gray{Float64}(0.5571459149735971) … Gray{Float64}(0.3445968864802627) Gray{Float64}(0.3467602362649874)]

# %% [markdown]
# ## 2.3 Choix du nombre $k$ de vecteurs singuliers à utiliser
#
# ### a) Tracez un graphique permettant de voir le pourcentage de la variance totale retenue en fonction du nombre de vecteur singuliers.

# %%
cumvar = cumsum(γ.^2)

ratio = cumvar / cumvar[end]

df = DataFrame(k = Int64[], Variance = Float64[])

for k in 1:length(ratio)
    push!(df, [k, ratio[k]])
end

plot(df, x=:k, y=:Variance, Geom.line)
# Out:
# Plot(...)

# %% [markdown]
# ### b) Calculez le pourcentage de la variance récupérée en utilisant 10, 50 et 70 composantes principales.

# %%
ratio[[10,50,70]]
# Out:
# 3-element Array{Float64,1}:
#  0.8053672725750084
#  0.9457957538269388
#  0.9627126959566592

# %% [markdown]
# # 3. Approximation d'une image à l'aide des vecteurs singuliers
#
# Soit $k$ le nombre de vecteurs singuliers retenus. Nous allons approximer le visage $\mathbf{z}_i$ à l'aide des $k$ premières vecteurs singuliers.
#
# Dénotons par $V_k$ la matrice des $k$ premiers vecteurs singuliers de $V$. On cherche à trouver la combinaison linéaire des $k$ vecteurs qui approxime le visage $\mathbf{z}_i$ :
#
# $$ \mathbf{Z}_i = V_k \mathbf{w} + \varepsilon ; $$
#
# où $\mathbf{w}$ correspond au vecteur des poids de la combinaison linéaire et $\varepsilon$ correspond à l'erreur que l'on fait. L'erreur serait nulle si on utilisait tous les vecteurs singuliers.
#
# On se retrouve donc dans un problème de régression où la variable d'intérêt est l'image du visage et où les variables explicatives sont les vecteur singuliers $V_k$. Pour trouver les coefficients de régression $\mathbf{w}$, il suffit de procéder comme au chapitre 2 :
#
# $$ \mathbf{\hat{w}} = (V_k^\top V_k)^{-1} V_k^\top \mathbf{z}_i . $$
#
# Or, puisque la matrice des vecteurs singuliers est orthonormales, la dernière équation se simplifie à l'expression suivante :
#
# $$ \mathbf{\hat{w}} = V_k^\top \mathbf{z}_i . $$
#
# Le visage $\mathbf{z}_i$ projeté dans les k premières composantes principales, dénoté par $\mathbf{\hat{z}}_i$,  est obtenue avec l'équation suivante :
#
# $$ \mathbf{\hat{z}}_i = V_k \mathbf{\hat{w}}.$$
#
#
#
# **Remarque :** On pourrait être de tenté de calculer la projection du visage en une seule étape, en remplaçant $\mathbf{w}$ par son expression :
#
# $$ \mathbf{\hat{z}}_i = V_k \mathbf{\hat{w}} = V_k V_k^\top \mathbf{z}^\top_i.$$
#
# La matrice $V_k V_k^\top$ correspond à une matrice de projection dans l'espace des $k$ premières composantes principales. Il faut cependant traiter le produit matricielle $V_k V_k^\top$ avec attention pour obtenir des résultats précis et rapides. Il est souvent plus judicieux de procéder en deux étapes :
# 1. Calculer les poids $\mathbf{\hat{w}}$.
# 2. Calculer la projection de l'image $\mathbf{\hat{z}}_i^\top = V_k \mathbf{\hat{w}}$.

# %% [markdown]
# ## 3.1 Approximation du visage 1 avec les 10 premiers vecteurs singuliers

# %%
i = 1
k = 10

Vk = V[:,1:k]
zᵢ = Z[i,:]
# Out:
# 32256-element Array{Float64,1}:
#   18.0
#   18.0
#   17.0
#   17.0
#   18.0
#   20.0
#   17.0
#   18.0
#   21.0
#   20.0
#   17.0
#   20.0
#   21.0
#    ⋮
#  -15.0
#  -12.0
#  -14.0
#  -14.0
#   -4.0
#  -15.0
#  -20.0
#  -22.0
#  -26.0
#  -25.0
#  -26.0
#  -30.0

# %% [markdown]
# ### a) Calculez les coefficients ŵ

# %%
ŵ = Vk'*zᵢ
# Out:
# 10-element Array{Float64,1}:
#  -1241.5693738402383
#  -2424.3998468678715
#   -137.3353833701637
#  -1040.5032513557062
#   -248.90687131996626
#    420.3773679050208
#   -400.989977234314
#    350.98431277806037
#   -182.68783820369373
#   1076.5064365789542

# %% [markdown]
# ### b) Calculez l'approximation du visage

# %%
ẑᵢ = Vk*ŵ
# Out:
# 32256-element Array{Float64,1}:
#  10.30944545338104
#  10.221658874141962
#  10.593204420377875
#  11.14470807330032
#  12.111674686898343
#  12.504248366043575
#  12.42626671476232
#  12.409819492069616
#  13.025229491032736
#  12.611875261826057
#  12.942745847748954
#  13.312671856648295
#  13.3144574018193
#   ⋮
#  -1.7409419611835268
#  -2.478389300058964
#  -3.144911695105478
#  -3.519362144583035
#  -4.193714405675414
#  -4.967282346229284
#  -4.71108381356424
#  -4.289919014014536
#  -4.557502026436567
#  -5.955926115835943
#  -8.455283730139517
#  -9.714906066303154

# %% [markdown]
# ### c) Affichez le visage original et son approximation
#
# Vous pouvez ajouter le visage moyen pour une meilleure interprétation

# %%
[imshow(X[i,:],(m₁, m₂)) imshow(ẑᵢ .+ X̄, (m₁, m₂))]
# Out:
# 192×336 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.299578)   …  Gray{Float64}(0.215199)
#  Gray{Float64}(0.303797)      Gray{Float64}(0.213523)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.21322)
#  Gray{Float64}(0.295359)      Gray{Float64}(0.214604)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.216088)
#  Gray{Float64}(0.308017)   …  Gray{Float64}(0.218209)
#  Gray{Float64}(0.295359)      Gray{Float64}(0.217399)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.224637)
#  Gray{Float64}(0.312236)      Gray{Float64}(0.224416)
#  Gray{Float64}(0.308017)      Gray{Float64}(0.224998)
#  Gray{Float64}(0.291139)   …  Gray{Float64}(0.228507)
#  Gray{Float64}(0.303797)      Gray{Float64}(0.230941)
#  Gray{Float64}(0.308017)      Gray{Float64}(0.235429)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.113924)   …  Gray{Float64}(0.0662084)
#  Gray{Float64}(0.0886076)     Gray{Float64}(0.0557259)
#  Gray{Float64}(0.0759494)     Gray{Float64}(0.0456714)
#  Gray{Float64}(0.0759494)     Gray{Float64}(0.0373791)
#  Gray{Float64}(0.0506329)     Gray{Float64}(0.0272773)
#  Gray{Float64}(0.0506329)  …  Gray{Float64}(0.0226102)
#  Gray{Float64}(0.0464135)     Gray{Float64}(0.0181227)
#  Gray{Float64}(0.0464135)     Gray{Float64}(0.0206637)
#  Gray{Float64}(0.0421941)     Gray{Float64}(0.0190493)
#  Gray{Float64}(0.0126582)     Gray{Float64}(0.0106123)
#  Gray{Float64}(0.0126582)  …  Gray{Float64}(0.00156636)
#  Gray{Float64}(0.0126582)     Gray{Float64}(0.0)

# %% [markdown]
# ## 3.2 Approximation du visage 1 avec les 50 premières vecteurs singuliers
#
# Reprenez les étapes précédentes mais cette fois en utilisant les 50 premiers vecteurs singuliers.

# %%
i = 1
k = 50

Vk = V[:,1:k]
zᵢ = Z[i,:]

ŵ = Vk'*zᵢ
ẑᵢ = Vk*ŵ

# Affichage de l'image originale et de l'approximation
[imshow(X[i,:],(m₁, m₂)) imshow(ẑᵢ .+ X̄, (m₁, m₂))]
# Out:
# 192×336 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.299578)   …  Gray{Float64}(0.267512)
#  Gray{Float64}(0.303797)      Gray{Float64}(0.27209)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.266907)
#  Gray{Float64}(0.295359)      Gray{Float64}(0.272495)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.275277)
#  Gray{Float64}(0.308017)   …  Gray{Float64}(0.26613)
#  Gray{Float64}(0.295359)      Gray{Float64}(0.26838)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.257465)
#  Gray{Float64}(0.312236)      Gray{Float64}(0.251051)
#  Gray{Float64}(0.308017)      Gray{Float64}(0.248665)
#  Gray{Float64}(0.291139)   …  Gray{Float64}(0.247716)
#  Gray{Float64}(0.303797)      Gray{Float64}(0.247552)
#  Gray{Float64}(0.308017)      Gray{Float64}(0.25556)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.113924)   …  Gray{Float64}(0.104182)
#  Gray{Float64}(0.0886076)     Gray{Float64}(0.0975477)
#  Gray{Float64}(0.0759494)     Gray{Float64}(0.0756814)
#  Gray{Float64}(0.0759494)     Gray{Float64}(0.0680803)
#  Gray{Float64}(0.0506329)     Gray{Float64}(0.0597818)
#  Gray{Float64}(0.0506329)  …  Gray{Float64}(0.0514551)
#  Gray{Float64}(0.0464135)     Gray{Float64}(0.0381836)
#  Gray{Float64}(0.0464135)     Gray{Float64}(0.0307763)
#  Gray{Float64}(0.0421941)     Gray{Float64}(0.0190355)
#  Gray{Float64}(0.0126582)     Gray{Float64}(0.0217172)
#  Gray{Float64}(0.0126582)  …  Gray{Float64}(0.0242664)
#  Gray{Float64}(0.0126582)     Gray{Float64}(0.0381279)

# %% [markdown]
# ## 3.3 Approximation du visage 1 avec les 70 premières vecteurs singuliers
#
# Reprenez les étapes précédentes mais cette fois en utilisant les 70 premiers vecteurs singuliers.

# %%
i = 1
k = 70

Vk = V[:,1:k]
zᵢ = Z[i,:]

ŵ = Vk'*zᵢ
ẑᵢ = Vk*ŵ

# Affichage de l'image originale et de l'approximation
[imshow(X[i,:],(m₁, m₂)) imshow(ẑᵢ .+ X̄, (m₁, m₂))]
# Out:
# 192×336 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.299578)   …  Gray{Float64}(0.274344)
#  Gray{Float64}(0.303797)      Gray{Float64}(0.274527)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.269496)
#  Gray{Float64}(0.295359)      Gray{Float64}(0.272796)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.278522)
#  Gray{Float64}(0.308017)   …  Gray{Float64}(0.267241)
#  Gray{Float64}(0.295359)      Gray{Float64}(0.26973)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.259607)
#  Gray{Float64}(0.312236)      Gray{Float64}(0.253251)
#  Gray{Float64}(0.308017)      Gray{Float64}(0.251565)
#  Gray{Float64}(0.291139)   …  Gray{Float64}(0.25266)
#  Gray{Float64}(0.303797)      Gray{Float64}(0.251851)
#  Gray{Float64}(0.308017)      Gray{Float64}(0.259184)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.113924)   …  Gray{Float64}(0.121761)
#  Gray{Float64}(0.0886076)     Gray{Float64}(0.116923)
#  Gray{Float64}(0.0759494)     Gray{Float64}(0.0975715)
#  Gray{Float64}(0.0759494)     Gray{Float64}(0.0911457)
#  Gray{Float64}(0.0506329)     Gray{Float64}(0.0838819)
#  Gray{Float64}(0.0506329)  …  Gray{Float64}(0.0742236)
#  Gray{Float64}(0.0464135)     Gray{Float64}(0.06187)
#  Gray{Float64}(0.0464135)     Gray{Float64}(0.0522967)
#  Gray{Float64}(0.0421941)     Gray{Float64}(0.0396248)
#  Gray{Float64}(0.0126582)     Gray{Float64}(0.0428385)
#  Gray{Float64}(0.0126582)  …  Gray{Float64}(0.0500882)
#  Gray{Float64}(0.0126582)     Gray{Float64}(0.0659648)

# %% [markdown]
# ## 3.3 Approximation du visage 29 avec les 50 premières vecteurs singuliers
#
# Reprenez les étapes précédentes mais cette fois avec le visage 29.

# %%
i = 29
k = 50

Vk = V[:,1:k]
zᵢ = Z[i,:]

ŵ = Vk'*zᵢ
ẑᵢ = Vk*ŵ

# Affichage de l'image originale et de l'approximation
[imshow(X[i,:],(m₁, m₂)) imshow(ẑᵢ .+ X̄, (m₁, m₂))]
# Out:
# 192×336 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.321285)  Gray{Float64}(0.317269)  …  Gray{Float64}(0.429454)
#  Gray{Float64}(0.293173)  Gray{Float64}(0.297189)     Gray{Float64}(0.425286)
#  Gray{Float64}(0.285141)  Gray{Float64}(0.293173)     Gray{Float64}(0.404849)
#  Gray{Float64}(0.273092)  Gray{Float64}(0.289157)     Gray{Float64}(0.411939)
#  Gray{Float64}(0.26506)   Gray{Float64}(0.277108)     Gray{Float64}(0.398365)
#  Gray{Float64}(0.261044)  Gray{Float64}(0.269076)  …  Gray{Float64}(0.400886)
#  Gray{Float64}(0.248996)  Gray{Float64}(0.240964)     Gray{Float64}(0.382205)
#  Gray{Float64}(0.216867)  Gray{Float64}(0.196787)     Gray{Float64}(0.379279)
#  Gray{Float64}(0.212851)  Gray{Float64}(0.208835)     Gray{Float64}(0.3627)
#  Gray{Float64}(0.172691)  Gray{Float64}(0.15261)      Gray{Float64}(0.330907)
#  Gray{Float64}(0.144578)  Gray{Float64}(0.144578)  …  Gray{Float64}(0.310382)
#  Gray{Float64}(0.120482)  Gray{Float64}(0.11245)      Gray{Float64}(0.298981)
#  Gray{Float64}(0.128514)  Gray{Float64}(0.11245)      Gray{Float64}(0.294737)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float64}(0.341365)  Gray{Float64}(0.353414)  …  Gray{Float64}(0.507874)
#  Gray{Float64}(0.329317)  Gray{Float64}(0.353414)     Gray{Float64}(0.500507)
#  Gray{Float64}(0.337349)  Gray{Float64}(0.353414)     Gray{Float64}(0.477984)
#  Gray{Float64}(0.337349)  Gray{Float64}(0.349398)     Gray{Float64}(0.478395)
#  Gray{Float64}(0.321285)  Gray{Float64}(0.329317)     Gray{Float64}(0.461793)
#  Gray{Float64}(0.309237)  Gray{Float64}(0.317269)  …  Gray{Float64}(0.478768)
#  Gray{Float64}(0.301205)  Gray{Float64}(0.317269)     Gray{Float64}(0.450332)
#  Gray{Float64}(0.297189)  Gray{Float64}(0.309237)     Gray{Float64}(0.45294)
#  Gray{Float64}(0.289157)  Gray{Float64}(0.305221)     Gray{Float64}(0.441332)
#  Gray{Float64}(0.281124)  Gray{Float64}(0.297189)     Gray{Float64}(0.438159)
#  Gray{Float64}(0.269076)  Gray{Float64}(0.289157)  …  Gray{Float64}(0.431952)
#  Gray{Float64}(0.26506)   Gray{Float64}(0.281124)     Gray{Float64}(0.428988)

# %% [markdown]
# # 4. Reconnaissance faciale
#
#
# L'idée de la reconnaissance faciale consiste à comparer le vecteur des coefficient $\mathbf{\hat{w}}$ de l'image à reconnaître avec les vecteurs poids des images de l'ensemble d'entraînement. C'est une comparaison assez facile à faire car ce vecteur est de dimension raisonnable comparativement aux images originales. En effet, dans notre cas, si on prend 50 vecteurs singuliers, le vecteur des coefficient est un vecteur colonne de taille 50. On peut donc résumer toutes les images par leur vecteur des coefficients de taille 50.
#
# Pour savoir, si une nouvelle image représente une personne présente dans l'ensemble d'entraînement, on n'a qu'à comparer son vecteur des coefficients avec chacun des vecteurs des coefficients de l'ensemble d'entraînement. Cette comparaison est facile, rapide et efficace car les vecteurs sont de tailles raisonnables. Si la différence entre les vecteurs est très grande, cela suggère que la personne est inconnue de l'ensemble d'entraînement. Si la différence est petite avec un des vecteurs de coefficients, cela suggère qu'il s'agit de la même personne. Le seuil doit être ajusté avec de la validation croisée.
#
# Dans cette section, vous déciderez si une nouvelle image de l'ensemble test représente un personne connue ou inconnue. Vous le ferez en complétant les étapes suivantes :
#
# 1. Calculez les poids de toutes les images de l'ensemble d'entraînement.
# 2. Calculez les poids de l'image de test.
# 3. Calculez la distance entre les vecteurs poids des images d'entraînement et celui de l'image de test.
# 4. Identifiez l'image de l'ensemble d'entraînement la plus proche de l'image de test.
# 5. Décidez si le visage se retrouve dans l'échantillon d'entraînement ou s'il est inconnu.

# %% [markdown]
# ### 4.1 Calculez les poids de toutes les images de l'ensemble d'entraînement
#
# Prenez pour l'instant $k = 50$ composantes.

# %%
k = 50

Vk = V[:,1:k]

W = Vk'*Z'
# Out:
# 50×784 Array{Float64,2}:
#  -1241.57    -1653.02    -1529.57     -287.801   …  -11833.8     -10835.6
#  -2424.4     -3249.17    -2003.23     -589.972        4271.66      5716.2
#   -137.335    2845.4      6374.51    -2545.18         3903.22     -4512.72
#  -1040.5      -784.661    -256.657   -1119.35          902.167      794.443
#   -248.907    -328.106    -599.941    -252.628        3181.88      2324.45
#    420.377     100.073    -929.415     514.241   …   -2487.38     -1675.27
#   -400.99      -65.1004     55.8987   -365.714         -10.083      404.175
#    350.984     391.872     580.52      659.419         511.712    -1514.95
#   -182.688    -947.937   -1422.22     -185.939          45.6406    -808.092
#   1076.51     1001.23      232.528    1063.37         1863.33      -605.055
#   -132.971     -54.2153     29.6504   -470.463   …     943.191     1574.16
#   1000.39      950.909     779.646    1061.6           512.839      579.797
#   -812.87     -694.712    -211.432   -1154.02         -815.558    -1198.77
#      ⋮                                           ⋱
#   -360.17     -404.56      -20.5857   -672.44         -223.326     -222.991
#   -168.226     -52.9491    -68.7643   -217.492         718.652      168.949
#    142.857     344.386     283.214     136.406   …     493.14      -555.096
#    152.526     223.181     377.97      -73.1244        864.565     1598.6
#     48.6067   -224.097    -485.846     174.933       -1004.95      -563.35
#   -203.4      -150.252      54.7088   -224.428         152.825     -189.619
#     94.5699    406.993     478.046      75.6388       -238.424     -299.51
#   -318.629    -187.184     204.134    -382.454   …     352.224       60.2797
#     47.9425    -59.6352   -429.529     212.9           394.461      627.074
#   -209.735     336.614     840.164    -336.805        -108.97        93.4469
#    289.403     325.723     333.509     179.053        -268.858      609.107
#    -52.3688    216.813     576.988    -463.929         137.197     -364.066

# %% [markdown]
# ### 4.2 Calculez les poids de l'image de test
#
# Prenons d'abord la première image de l'échantillon de test. Il faut charger l'image, retirer le visage moyen et calculer les poids.

# %%
# Récupération de tous les noms de fichiers de l'échantillon d'entraînement
file = readdir("Test")
testFileName = ["Test/"*file[i] for i=1:length(file)];

# %%
# conversion de l'image de test en intensités de gris et retrait du visage moyen

j = 1  # j^e image de l'échantillon de test

y = imgrayconvert(testFileName[j]) - X̄
# Out:
# 32256-element Array{Int64,1}:
#   32
#   29
#   27
#   29
#   33
#   32
#   36
#   36
#   32
#   31
#   30
#   32
#   34
#    ⋮
#  -13
#  -19
#  -21
#  -21
#  -20
#  -21
#  -21
#  -26
#  -28
#  -24
#  -26
#  -27

# %%
# Calcul des poids de l'image de l'échantillon de test
ŵ = Vk'*y
# Out:
# 50-element Array{Float64,1}:
#    352.7437297666436
#  -2881.814317555777
#  -1477.9970244534352
#  -1078.8372867130724
#   -334.89528362410783
#    558.6922704438296
#   -389.9359206149321
#    770.3403839238624
#   -476.26865647529553
#   1127.277865610702
#   -506.36547342731353
#    944.6672296276703
#  -1145.399209366282
#      ⋮
#   -692.5288006002643
#   -194.9514238167257
#    191.28422337006452
#      0.6204383632065782
#     49.5848962175698
#   -177.66961472220953
#    190.50354990262224
#   -208.75542666651992
#    129.94513027397946
#   -166.55810805954374
#    194.97228514770683
#   -388.5866372047757

# %% [markdown]
# ### 4.3 Calculez la distance euclidienne entre les vecteurs poids des images d'entraînement et celui de l'image de test.

# %%
d = sum( (W .- ŵ).^2, dims=1 )
# Out:
# 1×784 Array{Float64,2}:
#  6.04352e6  2.84337e7  8.446e7  7.60379e6  …  3.07669e8  2.90303e8  2.66239e8

# %% [markdown]
# ### 4.4 Identifiez l'image de l'ensemble d'entraînement la plus proche de l'image de test.

# %%
minval, ind = findmin(d)
ind = ind[1]

[load(testFileName[j]) load(trainFileName[ind])]
# Out:
# 192×336 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.369)  Gray{N0f8}(0.376)  …  Gray{N0f8}(0.278)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.38)      Gray{N0f8}(0.251)
#  Gray{N0f8}(0.353)  Gray{N0f8}(0.369)     Gray{N0f8}(0.243)
#  Gray{N0f8}(0.357)  Gray{N0f8}(0.392)     Gray{N0f8}(0.247)
#  Gray{N0f8}(0.373)  Gray{N0f8}(0.388)     Gray{N0f8}(0.247)
#  Gray{N0f8}(0.369)  Gray{N0f8}(0.376)  …  Gray{N0f8}(0.235)
#  Gray{N0f8}(0.384)  Gray{N0f8}(0.38)      Gray{N0f8}(0.227)
#  Gray{N0f8}(0.384)  Gray{N0f8}(0.38)      Gray{N0f8}(0.22)
#  Gray{N0f8}(0.369)  Gray{N0f8}(0.365)     Gray{N0f8}(0.224)
#  Gray{N0f8}(0.365)  Gray{N0f8}(0.365)     Gray{N0f8}(0.227)
#  Gray{N0f8}(0.357)  Gray{N0f8}(0.373)  …  Gray{N0f8}(0.231)
#  Gray{N0f8}(0.365)  Gray{N0f8}(0.384)     Gray{N0f8}(0.231)
#  Gray{N0f8}(0.373)  Gray{N0f8}(0.392)     Gray{N0f8}(0.235)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.184)  …  Gray{N0f8}(0.114)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.157)     Gray{N0f8}(0.122)
#  Gray{N0f8}(0.133)  Gray{N0f8}(0.149)     Gray{N0f8}(0.11)
#  Gray{N0f8}(0.137)  Gray{N0f8}(0.141)     Gray{N0f8}(0.106)
#  Gray{N0f8}(0.145)  Gray{N0f8}(0.157)     Gray{N0f8}(0.141)
#  Gray{N0f8}(0.165)  Gray{N0f8}(0.173)  …  Gray{N0f8}(0.098)
#  Gray{N0f8}(0.149)  Gray{N0f8}(0.141)     Gray{N0f8}(0.075)
#  Gray{N0f8}(0.165)  Gray{N0f8}(0.153)     Gray{N0f8}(0.067)
#  Gray{N0f8}(0.133)  Gray{N0f8}(0.133)     Gray{N0f8}(0.051)
#  Gray{N0f8}(0.098)  Gray{N0f8}(0.145)     Gray{N0f8}(0.055)
#  Gray{N0f8}(0.114)  Gray{N0f8}(0.122)  …  Gray{N0f8}(0.055)
#  Gray{N0f8}(0.11)   Gray{N0f8}(0.106)     Gray{N0f8}(0.043)

# %% [markdown]
# ### 4.5 Décidez si le visage se retrouve dans l'échantillon d'entraînement ou s'il est inconnu.
#
# Si la distance minimale entre les poids des images d'entraînement et des poids de l'image de test, alors on statuera que le visage est inconnu. Il faut définir cependant définir ce seuil à l'aide de la validation croisée. Tentez d'utiliser le seuil de (3500)^2 et refaites les étapes du numéro 4 avec les autres images de l'ensemble de test.

# %%
if minval > 3500^2
    println("Le visage est inconnu.")
else
    println("Le visage est connu.")
end
# Out:
# Le visage est connu.

# %%
# # Récupération des noms des personnes sur les images de l'ensemble d'entraînement
# ind1 = findfirst(isequal('/'),trainFileName[1])
# ind2 = findfirst(isequal('_'),trainFileName[1])
# trainPerson = [trainFileName[i][ind1+1:ind2-1] for i=1:length(trainFileName)];
